# %%
import sc2reader

replay = sc2reader.load_replay('test.SC2Replay')

for event in replay.events:
    if not hasattr(event, 'location'):
        event.location=(0,0)
    print(f'{event.name} at {event.location}: {event.frame} at {event.second} seconds')

class Parser():
    def __init__(self, path):
        self.path = path
# Out:
# PlayerSetupEvent at (0, 0): 0 at 0 seconds
# PlayerSetupEvent at (0, 0): 0 at 0 seconds
# UnitBornEvent at (98, 139): 0 at 0 seconds
# UnitBornEvent at (98, 17): 0 at 0 seconds
# UnitBornEvent at (23, 14): 0 at 0 seconds
# UnitBornEvent at (69, 137): 0 at 0 seconds
# UnitBornEvent at (151, 101): 0 at 0 seconds
# UnitBornEvent at (84, 132): 0 at 0 seconds
# UnitBornEvent at (20, 110): 0 at 0 seconds
# UnitBornEvent at (147, 76): 0 at 0 seconds
# UnitBornEvent at (22, 15): 0 at 0 seconds
# UnitBornEvent at (68, 141): 0 at 0 seconds
# UnitBornEvent at (79, 14): 0 at 0 seconds
# UnitBornEvent at (66, 142): 0 at 0 seconds
# UnitBornEvent at (18, 21): 0 at 0 seconds
# UnitBornEvent at (44, 42): 0 at 0 seconds
# UnitBornEvent at (49, 33): 0 at 0 seconds
# UnitBornEvent at (17, 56): 0 at 0 seconds
# UnitBornEvent at (24, 59): 0 at 0 seconds
# UnitBornEvent at (45, 39): 0 at 0 seconds
# UnitBornEvent at (26, 45): 0 at 0 seconds
# UnitBornEvent at (117, 32): 0 at 0 seconds
# ...

# %%
dir(replay.events[2])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_str_prefix',
#  'control_pid',
#  'frame',
#  'load_context',
#  'location',
#  'name',
#  'second',
#  'unit',
#  'unit_controller',
#  'unit_id',
#  'unit_id_index',
#  'unit_id_recycle',
#  'unit_type_name',
#  'unit_upkeeper',
#  'upkeep_pid',
#  'x',
#  'y']

# %%
replay.events[2].unit
# Out:
# LabMineralField [1]

# %%
selection = []
for event in replay.events:
    if event.name == "PlayerStatsEvent":
        selection.append(event)

# %%
dir(selection[17])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_str_prefix',
#  'ff_minerals_lost_army',
#  'ff_minerals_lost_economy',
#  'ff_minerals_lost_technology',
#  'ff_vespene_lost_army',
#  'ff_vespene_lost_economy',
#  'ff_vespene_lost_technology',
#  'food_made',
#  'food_used',
#  'frame',
#  'load_context',
#  'location',
#  'minerals_collection_rate',
#  'minerals_current',
#  'minerals_killed',
#  'minerals_killed_army',
#  'minerals_killed_economy',
#  'minerals_killed_technology',
#  'minerals_lost',
#  'minerals_lost_army',
#  'minerals_lost_economy',
#  'minerals_lost_technology',
# ...

# %%
selection[17].stats
# Out:
# {0: 95,
#  1: 0,
#  2: 783,
#  3: 0,
#  4: 17,
#  5: 0,
#  6: 125,
#  7: 150,
#  8: 0,
#  9: 0,
#  10: 0,
#  11: 0,
#  12: 1350,
#  13: 0,
#  14: 0,
#  15: 0,
#  16: 0,
#  17: 0,
#  18: 0,
#  19: 0,
#  20: 0,
#  21: 0,
#  22: 0,
#  23: 0,
#  24: 0,
#  25: 0,
#  26: 0,
#  27: 0,
#  28: 0,
#  29: 73728,
#  30: 94208,
#  31: 0,
#  32: 0,
#  33: 0,
#  34: 0,
#  35: 0,
#  36: 0,
#  37: 0,
#  38: 0}

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 selection[17].resources_used_in_progress_army
#
# AttributeError: 'PlayerStatsEvent' object has no attribute 'resources_used_in_progress_army'

# %%
dir(replay)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_datapack',
#  '_get_reader',
#  '_read_data',
#  'active_units',
#  'amm',
#  'archive',
#  'attributes',
#  'base_build',
#  'battle_net',
#  'build',
#  'category',
#  'client',
#  'clients',
#  'competitive',
#  'computer',
#  'computers',
#  'cooperative',
#  'datapack',
#  'date',
#  'end_time',
#  'entities',
#  'entity',
#  'events',
#  'expansion',
#  'factory',
#  'filehash',
#  'filename',
#  'frames',
#  'game_events',
#  'game_fps',
#  'game_length',
#  'game_type',
#  'hero_duplicates_allowed',
#  'human',
#  'humans',
# ...

# %%
replay.load_players()

# %%
replay.load_player_stats()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 replay.load_player_stats()
#
# AttributeError: 'Replay' object has no attribute 'load_player_stats'
